# %% [markdown]
# # Goal of This File

# %% [markdown]
# Retrieve the meaningfull data accross 12 stack overflow csv file that I need to build the ML Model to predict canadian salary. Because each file has its own csv structure (column name, type of data, etc). I need to build a unified view to access all this data (data integration).
#
# The columns I have to find: ["Year","OrgSize","Industry","Experience","Title","Country","Salary"]

# %% [markdown]
# I will build this massive unified view incrementaly, by dealing with each csv file by year.
# Each of the unified view constructed for each csv file will be appended to the file `stack-overflow-canada.csv`.

# %% [markdown]
# To Run this file you will need to download the stack overflow survey csv file from 2011 to 2023. And store them in the folder `Canadian Data/Stack Overflow/`

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
basePath = "../Canadian Data/Stack Overflow/"
canadianDataFileName = "stack-overflow-canada.csv"
countryInterestedIn = "Canada"

# %%
ColumnToHave = ["Year","OrgSize","Industry","Experience","Title","Country","Salary"]

# %% [markdown]
# ## 2023

# %%
data2023 = pd.read_csv(f"{basePath}2023.csv")
columns2023 = ["OrgSize","Industry","YearsCodePro","DevType","Country","ConvertedCompYearly"]
len(data2023.columns)
# Out:
# 84

# %%
canadaData2023 = data2023[data2023["Country"]=="Canada"][columns2023]
canadaData2023["Year"] = 2023
canadaData2023 = canadaData2023.rename(columns={"YearsCodePro":"Experience", "DevType":"Title", "ConvertedCompYearly":"Salary"})
canadaData2023 = canadaData2023[ColumnToHave]
canadaData2023
# Out:
#        Year                                            OrgSize  \
# 40     2023                               100 to 499 employees
# 45     2023                               500 to 999 employees
# 114    2023                                                NaN
# 140    2023  Just me - I am a freelancer, sole proprietor, ...
# 164    2023                                 10 to 19 employees
# ...     ...                                                ...
# 89120  2023                           10,000 or more employees
# 89142  2023                                                NaN
# 89148  2023                           10,000 or more employees
# 89155  2023                                 20 to 99 employees
# 89157  2023                           1,000 to 4,999 employees
#
#                                                 Industry        Experience  \
# 40                                                 Other                 2
# ...

# %%
canadaData2023.to_csv(f'{basePath}{canadianDataFileName}', index=False)

# %% [markdown]
# ## 2022

# %%
data2022 = pd.read_csv(f"{basePath}2022.csv")
columns2022 = ["OrgSize","YearsCodePro","DevType","Country","ConvertedCompYearly"]
len(data2022.columns)
# Out:
# 79

# %%
data2022.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
canadaData2022 = data2022[data2022["Country"]=="Canada"][columns2022]
canadaData2022["Year"] = 2022
canadaData2022["Industry"] = pd.NA
canadaData2022.columns
canadaData2022 = canadaData2022.rename(columns={"YearsCodePro":"Experience", "DevType":"Title", "ConvertedCompYearly":"Salary"})
canadaData2022 = canadaData2022[ColumnToHave]
canadaData2022
# Out:
#        Year                   OrgSize Industry Experience  \
# 1      2022                       NaN     <NA>        NaN
# 22     2022      100 to 499 employees     <NA>         20
# 32     2022                       NaN     <NA>        NaN
# 36     2022        20 to 99 employees     <NA>          7
# 60     2022          2 to 9 employees     <NA>          4
# ...     ...                       ...      ...        ...
# 73082  2022                       NaN     <NA>        NaN
# 73087  2022                       NaN     <NA>        NaN
# 73110  2022        20 to 99 employees     <NA>          9
# 73123  2022  10,000 or more employees     <NA>          7
# 73267  2022                       NaN     <NA>          5
#
#                                                    Title Country   Salary
# 1                                                    NaN  Canada      NaN
# 22                                   Developer, back-end  Canada  97605.0
# ...

# %%
canadaData2022.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2021

# %%
data2021 = pd.read_csv(f"{basePath}2021.csv")
columns2021 = ["OrgSize","YearsCodePro","DevType","Country","ConvertedCompYearly"]
len(data2021.columns)
# Out:
# 48

# %%
canadaData2021 = data2021[data2021["Country"]=="Canada"][columns2021]
canadaData2021["Year"] = 2021
canadaData2021["Industry"] = pd.NA
canadaData2021.columns
canadaData2021 = canadaData2021.rename(columns={"YearsCodePro":"Experience", "DevType":"Title", "ConvertedCompYearly":"Salary"})
canadaData2021 = canadaData2021[ColumnToHave]
canadaData2021
# Out:
#        Year                   OrgSize Industry        Experience  \
# 17     2021      500 to 999 employees     <NA>                 6
# 67     2021      100 to 499 employees     <NA>                10
# 77     2021      500 to 999 employees     <NA>                 8
# 86     2021        20 to 99 employees     <NA>                17
# 89     2021                       NaN     <NA>               NaN
# ...     ...                       ...      ...               ...
# 83282  2021  5,000 to 9,999 employees     <NA>  Less than 1 year
# 83385  2021      100 to 499 employees     <NA>                 2
# 83387  2021        20 to 99 employees     <NA>                25
# 83432  2021  10,000 or more employees     <NA>  Less than 1 year
# 83437  2021        20 to 99 employees     <NA>                 3
#
#                                                    Title Country    Salary
# 17     Developer, front-end;Developer, full-stack;Dev...  Canada   46135.0
# ...

# %%
canadaData2021.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2020

# %%
data2020 = pd.read_csv(f"{basePath}2020.csv")
columns2020 = ["OrgSize","YearsCodePro","DevType","Country","ConvertedComp"]
len(data2020.columns)
# Out:
# 61

# %%
canadaData2020 = data2020[data2020["Country"]=="Canada"][columns2020]
canadaData2020["Year"] = 2020
canadaData2020["Industry"] = pd.NA
canadaData2020.columns
canadaData2020 = canadaData2020.rename(columns={"YearsCodePro":"Experience", "DevType":"Title", "ConvertedComp":"Salary"})
canadaData2020 = canadaData2020[ColumnToHave]
canadaData2020
# Out:
#        Year                   OrgSize Industry Experience  \
# 25     2020      100 to 499 employees     <NA>         10
# 31     2020        10 to 19 employees     <NA>         10
# 50     2020      100 to 499 employees     <NA>          7
# 65     2020                       NaN     <NA>        NaN
# 74     2020  10,000 or more employees     <NA>        NaN
# ...     ...                       ...      ...        ...
# 64238  2020                       NaN     <NA>         24
# 64273  2020                       NaN     <NA>        NaN
# 64289  2020                       NaN     <NA>        NaN
# 64294  2020                       NaN     <NA>        NaN
# 64441  2020                       NaN     <NA>        NaN
#
#                                                    Title Country    Salary
# 25                                 Developer, full-stack  Canada   71093.0
# 31     Developer, back-end;Developer, desktop or ente...  Canada   31764.0
# ...

# %%
canadaData2020.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2019

# %%
data2019 = pd.read_csv(f"{basePath}2019.csv")
columns2019 = ["OrgSize","YearsCodePro","DevType","Country","ConvertedComp"]
len(data2019.columns)
# Out:
# 85

# %%
copy2019 = data2019.copy()

# %%
copy2019 = copy2019.dropna()
# Out:
# 19         Android Studio;Visual Studio;Visual Studio Code
# 38       Notepad++;Sublime Text;Vim;Visual Studio;Visua...
# 43               IntelliJ;Visual Studio;Visual Studio Code
# 82                     Sublime Text;Vim;Visual Studio Code
# 103             Notepad++;Visual Studio;Visual Studio Code
#                                ...
# 88161                       Eclipse;Notepad++;Sublime Text
# 88178                                   IntelliJ;Notepad++
# 88236      Android Studio;Visual Studio;Visual Studio Code
# 88301           Notepad++;Visual Studio;Visual Studio Code
# 88325             IntelliJ;Sublime Text;Visual Studio Code
# Name: DevEnviron, Length: 3475, dtype: object

# %%
education_rows = copy2019[copy2019.applymap(lambda x: 'Marketing' in str(x)).any(axis=1)]
education_rows
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 13560       13623                     I am a developer by profession      Yes
# 15413       15494                     I am a developer by profession      Yes
# 17840       17939                     I am a developer by profession      Yes
# 19750       19859                     I am a developer by profession      Yes
# 32504       32701                     I am a developer by profession      Yes
# 36646       36874                     I am a developer by profession      Yes
# 37347       37577                     I am a developer by profession      Yes
# 41102       41365                     I am a developer by profession      Yes
# 44105       44385                     I am a developer by profession      Yes
# 45303       45593  I am not primarily a developer, but I write co...      Yes
# 56240       56598                     I am a developer by profession      Yes
# ...

# %%
# Assuming 'row_index' is the index of the row you want to print
row_index = 3  # Replace with the desired row index

# Use loc to access the row by its label
row_values = education_rows.iloc[row_index]

# Iterate over the columns and print the values
for column, value in row_values.items():
    print(f"{column}: {value}")
# Out:
# Respondent: 19859
# MainBranch: I am a developer by profession
# Hobbyist: Yes
# OpenSourcer: Less than once per year
# OpenSource: OSS is, on average, of HIGHER quality than proprietary / closed source software
# Employment: Employed full-time
# Country: United States
# Student: No
# EdLevel: Associate degree
# UndergradMajor: Web development or web design
# EduOther: Taken an online course in programming or software development (e.g. a MOOC);Received on-the-job training in software development;Taught yourself a new language, framework, or tool without taking a formal course
# OrgSize: 20 to 99 employees
# DevType: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test;Marketing or sales professional;System administrator
# YearsCode: 6
# Age1stCode: 22
# YearsCodePro: 5
# CareerSat: Neither satisfied nor dissatisfied
# JobSat: Slightly dissatisfied
# MgrIdiot: Somewhat confident
# MgrMoney: Yes
# MgrWant: Not sure
# ...

# %%
canadaData2019 = data2019[data2019["Country"]=="Canada"][columns2019]
canadaData2019["Year"] = 2019
canadaData2019["Industry"] = pd.NA
canadaData2019 = canadaData2019.rename(columns={"YearsCodePro":"Experience", "DevType":"Title", "ConvertedComp":"Salary"})
canadaData2019 = canadaData2019[ColumnToHave]
canadaData2019
# Out:
#        Year                   OrgSize Industry Experience  \
# 5      2019                       NaN     <NA>          3
# 11     2019                       NaN     <NA>        NaN
# 20     2019                       NaN     <NA>        NaN
# 30     2019                       NaN     <NA>        NaN
# 36     2019      100 to 499 employees     <NA>        NaN
# ...     ...                       ...      ...        ...
# 88771  2019                       NaN     <NA>          2
# 88801  2019  10,000 or more employees     <NA>          3
# 88838  2019                       NaN     <NA>          1
# 88855  2019                       NaN     <NA>        NaN
# 88878  2019                       NaN     <NA>        NaN
#
#                                                    Title Country    Salary
# 5      Data or business analyst;Data scientist or mac...  Canada  366420.0
# 11     Data or business analyst;Data scientist or mac...  Canada       NaN
# ...

# %%
canadaData2019.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2018

# %%
data2018 = pd.read_csv(f"{basePath}2018.csv")
columns2018 = ["CompanySize","YearsCodingProf","DevType","Country","SalaryType","ConvertedSalary"]
# data2018.columns
# Out:
# <ipython-input-60-88f4aadb2293>:1: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2018 = pd.read_csv(f"{basePath}2018.csv")

# %%
canadaData2018 = data2018[data2018["DevType"]!="Student"]
canadaData2018 = canadaData2018[canadaData2018["Country"]=="Canada"][canadaData2018["SalaryType"]!="Monthly"]
canadaData2018 = canadaData2018.dropna(subset=['SalaryType',"ConvertedSalary"])
canadaData2018 = canadaData2018[canadaData2018["SalaryType"]!="Weekly"]
canadaData2018 = canadaData2018[columns2018]
# Out:
# <ipython-input-61-53bc58a7ea8a>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   canadaData2018 = canadaData2018[canadaData2018["Country"]=="Canada"][canadaData2018["SalaryType"]!="Monthly"]

# %%
canadaData2018["Year"] = 2018
canadaData2018["Industry"] = pd.NA
canadaData2018 = canadaData2018.rename(columns={"YearsCodingProf":"Experience", "DevType":"Title", "ConvertedSalary":"Salary","CompanySize":"OrgSize"})
canadaData2018 = canadaData2018[ColumnToHave]
canadaData2018
# Out:
#        Year                   OrgSize Industry   Experience  \
# 190    2018        10 to 19 employees     <NA>  15-17 years
# 346    2018        20 to 99 employees     <NA>    6-8 years
# 359    2018      100 to 499 employees     <NA>    6-8 years
# 365    2018        20 to 99 employees     <NA>  12-14 years
# 425    2018  5,000 to 9,999 employees     <NA>    3-5 years
# ...     ...                       ...      ...          ...
# 86473  2018                       NaN     <NA>    0-2 years
# 86732  2018                       NaN     <NA>    3-5 years
# 86972  2018                       NaN     <NA>    0-2 years
# 87031  2018                       NaN     <NA>    0-2 years
# 88314  2018                       NaN     <NA>          NaN
#
#                                                    Title Country   Salary
# 190                                 Full-stack developer  Canada  74482.0
# 346              Back-end developer;Full-stack developer  Canada  52339.0
# ...

# %%
canadaData2018.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2017

# %%
data2017 = pd.read_csv(f"{basePath}2017.csv")
columns2017 = ["CompanySize","CompanyType", "YearsCodedJob","DeveloperType","Country","Currency","Salary"]
for c in data2017.columns:
  print(c)
# Out:
# Respondent
# Professional
# ProgramHobby
# Country
# University
# EmploymentStatus
# FormalEducation
# MajorUndergrad
# HomeRemote
# CompanySize
# CompanyType
# YearsProgram
# YearsCodedJob
# YearsCodedJobPast
# DeveloperType
# WebDeveloperType
# MobileDeveloperType
# NonDeveloperType
# CareerSatisfaction
# JobSatisfaction
# ExCoderReturn
# ExCoderNotForMe
# ExCoderBalance
# ExCoder10Years
# ExCoderBelonged
# ExCoderSkills
# ExCoderWillNotCode
# ExCoderActive
# PronounceGIF
# ProblemSolving
# BuildingThings
# LearningNewTech
# BoringDetails
# JobSecurity
# DiversityImportant
# AnnoyingUI
# FriendsDevelopers
# RightWrongWay
# UnderstandComputers
# SeriousWork
# InvestTimeTools
# WorkPayCare
# KinshipDevelopers
# ChallengeMyself
# CompetePeers
# ChangeWorld
# JobSeekingStatus
# HoursPerWeek
# LastNewJob
# AssessJobIndustry
# AssessJobRole
# AssessJobExp
# AssessJobDept
# AssessJobTech
# AssessJobProjects
# AssessJobCompensation
# AssessJobOffice
# AssessJobCommute
# AssessJobRemote
# ...

# %%
data2017[data2017["Country"]=="Canada"][columns2017]
# Out:
#                     CompanySize  \
# 11         100 to 499 employees
# 60     10,000 or more employees
# 187    1,000 to 4,999 employees
# 188                         NaN
# 192          20 to 99 employees
# ...                         ...
# 51184                       NaN
# 51191        20 to 99 employees
# 51198                       NaN
# 51206        20 to 99 employees
# 51389        10 to 19 employees
#
#                                              CompanyType     YearsCodedJob  \
# 11     Privately-held limited company, not in startup...      8 to 9 years
# 60                           Publicly-traded corporation  20 or more years
# 187        Government agency or public school/university      3 to 4 years
# 188                                                  NaN               NaN
# 192                               Venture-funded startup    10 to 11 years
# ...                                                  ...               ...
# ...

# %%
data2017[["YearsProgram",
"YearsCodedJob",
"YearsCodedJobPast"]]
# Out:
#            YearsProgram     YearsCodedJob YearsCodedJobPast
# 0          2 to 3 years               NaN               NaN
# 1         9 to 10 years               NaN               NaN
# 2      20 or more years  20 or more years               NaN
# 3        14 to 15 years     9 to 10 years               NaN
# 4      20 or more years    10 to 11 years               NaN
# ...                 ...               ...               ...
# 51387      6 to 7 years      1 to 2 years               NaN
# 51388      2 to 3 years               NaN               NaN
# 51389  Less than a year  Less than a year               NaN
# 51390    17 to 18 years      3 to 4 years               NaN
# 51391    14 to 15 years      5 to 6 years               NaN
#
# [51392 rows x 3 columns]

# %%
data2017[["DeveloperType","WebDeveloperType","MobileDeveloperType"]]
# Out:
#                                            DeveloperType WebDeveloperType  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                  Other              NaN
# 3                                                    NaN              NaN
# 4      Mobile developer; Graphics programming; Deskto...              NaN
# ...                                                  ...              ...
# 51387  Web developer; Developer with a statistics or ...              NaN
# 51388                                                NaN              NaN
# 51389               Web developer; Systems administrator              NaN
# 51390                    Web developer; Mobile developer              NaN
# 51391                                                NaN              NaN
#
#       MobileDeveloperType
# 0                     NaN
# ...

# %%
data2017[["Salary","ExpectedSalary"]]
# Out:
#          Salary  ExpectedSalary
# 0           NaN             NaN
# 1           NaN         37500.0
# 2      113750.0             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# ...         ...             ...
# 51387   58000.0             NaN
# 51388       NaN             NaN
# 51389       NaN             NaN
# 51390   40000.0             NaN
# 51391       NaN             NaN
#
# [51392 rows x 2 columns]

# %%
data2017["CompanyType"]
# Out:
# 0                                                      NaN
# 1        Privately-held limited company, not in startup...
# 2                              Publicly-traded corporation
# 3        Non-profit/non-governmental organization or pr...
# 4        Privately-held limited company, not in startup...
#                                ...
# 51387                                         I don't know
# 51388        Government agency or public school/university
# 51389                               I prefer not to answer
# 51390    Sole proprietorship or partnership, not in sta...
# 51391    Privately-held limited company, not in startup...
# Name: CompanyType, Length: 51392, dtype: object

# %%
canadaData2017 = data2017[data2017["Country"]=="Canada"][columns2017]
canadaData2017 = canadaData2017.dropna(subset=['Salary'])
# CAD to USD => 1CAD = 0.75USD
canadaData2017["Salary"] = canadaData2017["Salary"]*0.75
canadaData2017 = canadaData2017.drop("Currency", axis=1)
canadaData2017
# Out:
#                     CompanySize  \
# 192          20 to 99 employees
# 206          20 to 99 employees
# 209    1,000 to 4,999 employees
# 275    1,000 to 4,999 employees
# 320    10,000 or more employees
# ...                         ...
# 50654        10 to 19 employees
# 50753        20 to 99 employees
# 50839        20 to 99 employees
# 50962        20 to 99 employees
# 50974  1,000 to 4,999 employees
#
#                                              CompanyType     YearsCodedJob  \
# 192                               Venture-funded startup    10 to 11 years
# 206    Sole proprietorship or partnership, not in sta...     9 to 10 years
# 209        Government agency or public school/university      8 to 9 years
# 275                          Publicly-traded corporation    17 to 18 years
# 320                          Publicly-traded corporation  Less than a year
# ...                                                  ...               ...
# ...

# %%
canadaData2017["Year"] = 2017
canadaData2017 = canadaData2017.rename(columns={"CompanyType":"Industry", "YearsCodedJob":"Experience", "DeveloperType":"Title", "CompanySize":"OrgSize"})
canadaData2017 = canadaData2017[ColumnToHave]
canadaData2017
# Out:
#        Year                   OrgSize  \
# 192    2017        20 to 99 employees
# 206    2017        20 to 99 employees
# 209    2017  1,000 to 4,999 employees
# 275    2017  1,000 to 4,999 employees
# 320    2017  10,000 or more employees
# ...     ...                       ...
# 50654  2017        10 to 19 employees
# 50753  2017        20 to 99 employees
# 50839  2017        20 to 99 employees
# 50962  2017        20 to 99 employees
# 50974  2017  1,000 to 4,999 employees
#
#                                                 Industry        Experience  \
# 192                               Venture-funded startup    10 to 11 years
# 206    Sole proprietorship or partnership, not in sta...     9 to 10 years
# 209        Government agency or public school/university      8 to 9 years
# 275                          Publicly-traded corporation    17 to 18 years
# 320                          Publicly-traded corporation  Less than a year
# ...

# %%
canadaData2017.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2016

# %%
data2016 = pd.read_csv(f"{basePath}2016.csv")
columns2016 = ["company_size_range","industry", "experience_midpoint","occupation","country", "salary_midpoint"]
data2016.columns
# Out:
# Index(['Unnamed: 0', 'collector', 'country', 'un_subregion', 'so_region',
#        'age_range', 'age_midpoint', 'gender', 'self_identification',
#        'occupation', 'occupation_group', 'experience_range',
#        'experience_midpoint', 'salary_range', 'salary_midpoint',
#        'big_mac_index', 'tech_do', 'tech_want', 'aliens',
#        'programming_ability', 'employment_status', 'industry',
#        'company_size_range', 'team_size_range', 'women_on_team', 'remote',
#        'job_satisfaction', 'job_discovery', 'dev_environment',
#        'commit_frequency', 'hobby', 'dogs_vs_cats', 'desktop_os',
#        'unit_testing', 'rep_range', 'visit_frequency', 'why_learn_new_tech',
#        'education', 'open_to_new_job', 'new_job_value', 'job_search_annoyance',
#        'interview_likelihood', 'how_to_improve_interview_process',
#        'star_wars_vs_star_trek', 'agree_tech', 'agree_notice',
#        'agree_problemsolving', 'agree_diversity', 'agree_adblocker',
# ...

# %%
canadaData2016 = data2016[data2016["country"]==countryInterestedIn][columns2016]
canadaData2016 = canadaData2016.dropna(subset=['salary_midpoint'])
canadaData2016
# Out:
#           company_size_range           industry  experience_midpoint  \
# 842          10-19 employees  Finance / Banking                 13.0
# 843        500-999 employees      Manufacturing                 13.0
# 844        100-499 employees         Government                 13.0
# 845          20-99 employees  Software Products                 13.0
# 847    1,000-4,999 employees           Internet                 13.0
# ...                      ...                ...                  ...
# 53250        20-99 employees         Automotive                 13.0
# 53251        20-99 employees       Web Services                  8.0
# 53253      500-999 employees             Retail                  1.5
# 53254                    NaN                NaN                  8.0
# 53256      100-499 employees       Web Services                 13.0
#
#                      occupation country  salary_midpoint
# 842             Product manager  Canada          85000.0
# ...

# %%
canadaData2016["Year"] = 2016
canadaData2016 = canadaData2016.rename(columns={"industry":"Industry", "country":"Country","experience_midpoint":"Experience", "occupation":"Title", "company_size_range":"OrgSize", "salary_midpoint":"Salary"})
canadaData2016 = canadaData2016[ColumnToHave]
canadaData2016
# Out:
#        Year                OrgSize           Industry  Experience  \
# 842    2016        10-19 employees  Finance / Banking        13.0
# 843    2016      500-999 employees      Manufacturing        13.0
# 844    2016      100-499 employees         Government        13.0
# 845    2016        20-99 employees  Software Products        13.0
# 847    2016  1,000-4,999 employees           Internet        13.0
# ...     ...                    ...                ...         ...
# 53250  2016        20-99 employees         Automotive        13.0
# 53251  2016        20-99 employees       Web Services         8.0
# 53253  2016      500-999 employees             Retail         1.5
# 53254  2016                    NaN                NaN         8.0
# 53256  2016      100-499 employees       Web Services        13.0
#
#                           Title Country    Salary
# 842             Product manager  Canada   85000.0
# 843                       other  Canada   65000.0
# ...

# %%
canadaData2016.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2015

# %%
data2015 = pd.read_csv(f"{basePath}2015.csv",header=1)
columns2015 = ["Industry", "Years IT / Programming Experience","Occupation","Country", "Compensation: midpoint"]
# for c in data2015.columns:
  # print(c)
# Out:
# <ipython-input-77-b23259a46d7c>:1: DtypeWarning: Columns (5,108,121,196,197,198) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2015 = pd.read_csv(f"{basePath}2015.csv",header=1)

# %%
canadaData2015 = data2015[data2015["Country"]==countryInterestedIn][columns2015]
canadaData2015 = canadaData2015.dropna(subset=['Compensation: midpoint'])
canadaData2015 = canadaData2015[~canadaData2015['Compensation: midpoint'].isin(["Rather not say","Unemployed"])]
canadaData2015
# Out:
#            Industry Years IT / Programming Experience              Occupation  \
# 15       Consulting                      6 - 10 years  Back-end web developer
# 16       Consulting                      6 - 10 years  Back-end web developer
# 17       Consulting                       2 - 5 years  Back-end web developer
# 18       Consulting                       1 - 2 years  Back-end web developer
# 19       Consulting                         11+ years  Back-end web developer
# ...             ...                               ...                     ...
# 21971  Web Services                      6 - 10 years                     NaN
# 22791           NaN                         11+ years                     NaN
# 22809           NaN                       2 - 5 years                     NaN
# 22814           NaN                       1 - 2 years                     NaN
# 22880           NaN                         11+ years                     NaN
#
# ...

# %%
canadaData2015["Year"] = 2015
canadaData2015["OrgSize"] = pd.NA
canadaData2015 = canadaData2015.rename(columns={"Years IT / Programming Experience":"Experience", "Occupation":"Title", "Compensation: midpoint":"Salary"})
canadaData2015 = canadaData2015[ColumnToHave]
canadaData2015
# Out:
#        Year OrgSize      Industry    Experience                   Title  \
# 15     2015    <NA>    Consulting  6 - 10 years  Back-end web developer
# 16     2015    <NA>    Consulting  6 - 10 years  Back-end web developer
# 17     2015    <NA>    Consulting   2 - 5 years  Back-end web developer
# 18     2015    <NA>    Consulting   1 - 2 years  Back-end web developer
# 19     2015    <NA>    Consulting     11+ years  Back-end web developer
# ...     ...     ...           ...           ...                     ...
# 21971  2015    <NA>  Web Services  6 - 10 years                     NaN
# 22791  2015    <NA>           NaN     11+ years                     NaN
# 22809  2015    <NA>           NaN   2 - 5 years                     NaN
# 22814  2015    <NA>           NaN   1 - 2 years                     NaN
# 22880  2015    <NA>           NaN     11+ years                     NaN
#
#       Country Salary
# 15     Canada  50000
# 16     Canada  50000
# 17     Canada  70000
# ...

# %%
canadaData2015.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2014

# %%
data2014 = pd.read_csv(f"{basePath}2014.csv")
columns2014 = ["How many developers are employed at your company?","How would you best describe the industry you currently work in?", "How many years of IT/Programming experience do you have?","Which of the following best describes your occupation?","What Country do you live in?", "Including bonus, what is your annual compensation in USD?"]
# for c in data2014.columns:
#   print(c)

# %%
canadaData2014 = data2014[data2014["What Country do you live in?"]==countryInterestedIn][columns2014]
canadaData2014 = canadaData2014.dropna(subset=['Including bonus, what is your annual compensation in USD?'])
canadaData2014 = canadaData2014[columns2014]
canadaData2014 = canadaData2014[~canadaData2014['Including bonus, what is your annual compensation in USD?'].isin(["Rather not say","Student / Unemployed"])]
canadaData2014
# Out:
#      How many developers are employed at your company?  \
# 22                                           6/15/2014
# 53                                                 100
# 72                                            1/5/2014
# 123                                          6/15/2014
# 257                                          6/15/2014
# ...                                                ...
# 7570                                         6/15/2014
# 7583                                             16-30
# 7590                                            50-100
# 7604                                               NaN
# 7640                                             31-50
#
#      How would you best describe the industry you currently work in?  \
# 22                                    Software Products
# 53                                    Software Products
# 72                                                Other
# 123                                               Other
# ...

# %%
canadaData2014["Year"] = 2014
canadaData2014 = canadaData2014.rename(columns={"How many developers are employed at your company?":"OrgSize","How would you best describe the industry you currently work in?":"Industry", "How many years of IT/Programming experience do you have?":"Experience","Which of the following best describes your occupation?":"Title","What Country do you live in?":"Country", "Including bonus, what is your annual compensation in USD?":"Salary"})
canadaData2014 = canadaData2014[ColumnToHave]
canadaData2014
# Out:
#       Year    OrgSize           Industry Experience  \
# 22    2014  6/15/2014  Software Products  6/10/2014
# 53    2014        100  Software Products         11
# 72    2014   1/5/2014              Other         <2
# 123   2014  6/15/2014              Other         <2
# 257   2014  6/15/2014  Software Products   2/5/2014
# ...    ...        ...                ...        ...
# 7570  2014  6/15/2014       Web Services         11
# 7583  2014      16-30       Web Services         <2
# 7590  2014     50-100              Other  6/10/2014
# 7604  2014        NaN              Other         <2
# 7640  2014      31-50         Consulting   2/5/2014
#
#                                      Title Country               Salary
# 22              Desktop Software Developer  Canada    $60,000 - $80,000
# 53    Manager of Developers or Team Leader  Canada            >$140,000
# 72                    I don't work in tech  Canada    $20,000 - $40,000
# ...

# %%
canadaData2014.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2013

# %%
data2013 = pd.read_csv(f"{basePath}2013.csv")
columns2013 = ["Including yourself, how many developers are employed at your company?","How would you best describe the industry you currently work in?", "How many years of IT/Programming experience do you have?","Which of the following best describes your occupation?","What Country or Region do you live in?", "Including bonus, what is your annual compensation in USD?"]
# for c in data2013.columns:
#   print(c)
# Out:
# <ipython-input-85-e89f16453a8d>:1: DtypeWarning: Columns (46,48,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2013 = pd.read_csv(f"{basePath}2013.csv")

# %%
data2013[columns2013]
# Out:
#      Including yourself, how many developers are employed at your company?  \
# 0                                              Response
# 1                                                   100
# 2                                             6/15/2013
# 3                                             6/15/2013
# 4                                                   NaN
# ...                                                 ...
# 9738                                           1/5/2013
# 9739                                           1/5/2013
# 9740                                           1/5/2013
# 9741                                             50-100
# 9742                                           1/5/2013
#
#      How would you best describe the industry you currently work in?  \
# 0                                              Response
# 1                                     Finance / Banking
# 2                                                Retail
# ...

# %%
canadaData2013 = data2013[data2013["What Country or Region do you live in?"]==countryInterestedIn][columns2013]
canadaData2013 = canadaData2013.dropna(subset=['Including bonus, what is your annual compensation in USD?'])
canadaData2013 = canadaData2013[columns2013]
canadaData2013 = canadaData2013[~canadaData2013['Including bonus, what is your annual compensation in USD?'].isin(["Rather not say","Student / Unemployed"])]
canadaData2013
# canadaData2013['Including bonus, what is your annual compensation in USD?'].unique()
# Out:
#      Including yourself, how many developers are employed at your company?  \
# 28                                            6/15/2013
# 44                                                16-30
# 193                                                 100
# 194                                           6/15/2013
# 198                                               31-50
# ...                                                 ...
# 9627                                           1/5/2013
# 9642                                          6/15/2013
# 9690                                                100
# 9726                                           1/5/2013
# 9736                                           1/5/2013
#
#      How would you best describe the industry you currently work in?  \
# 28                                                Other
# 44                                         Web Services
# 193                                          Consulting
# ...

# %%
canadaData2013["Year"] = 2013
canadaData2013 = canadaData2013.rename(columns={"Including yourself, how many developers are employed at your company?":"OrgSize","How would you best describe the industry you currently work in?":"Industry", "How many years of IT/Programming experience do you have?":"Experience","Which of the following best describes your occupation?":"Title","What Country or Region do you live in?":"Country", "Including bonus, what is your annual compensation in USD?":"Salary"})
canadaData2013 = canadaData2013[ColumnToHave]
canadaData2013
# Out:
#       Year    OrgSize           Industry Experience  \
# 28    2013  6/15/2013              Other   2/5/2013
# 44    2013      16-30       Web Services  6/10/2013
# 193   2013        100         Consulting         11
# 194   2013  6/15/2013       Web Services         11
# 198   2013      31-50  Finance / Banking   2/5/2013
# ...    ...        ...                ...        ...
# 9627  2013   1/5/2013       Web Services  6/10/2013
# 9642  2013  6/15/2013              Other   2/5/2013
# 9690  2013        100       Web Services  6/10/2013
# 9726  2013   1/5/2013              Other         11
# 9736  2013   1/5/2013  Software Products  6/10/2013
#
#                                 Title Country               Salary
# 28         Desktop Software Developer  Canada    $60,000 - $80,000
# 44           Full-Stack Web Developer  Canada    $40,000 - $60,000
# 193          Full-Stack Web Developer  Canada            >$140,000
# 194   IT Staff / System Administrator  Canada    $40,000 - $60,000
# ...

# %%
canadaData2013.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2012

# %%
data2012 = pd.read_csv(f"{basePath}2012.csv",encoding='ISO-8859-1')
columns2012 = ["Which best describes the size of your company?","How would you best describe the industry you currently work in?", "How many years of IT/Programming experience do you have?","Which of the following best describes your occupation?","What Country or Region do you live in?", "Including bonus, what is your annual compensation in USD?"]
data2012.columns
# for c in data2012.columns:
#   print(c)
# Out:
# Index(['What Country or Region do you live in?',
#        'Which US State or Territory do you live in?', 'How old are you?',
#        'How many years of IT/Programming experience do you have?',
#        'How would you best describe the industry you currently work in?',
#        'Which best describes the size of your company?',
#        'Which of the following best describes your occupation?',
#        'What is your involvement in purchasing products or services for the company you work for? (You can choose more than one)',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'What types of purchases are you involved in?',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19',
#        'What is your budget for outside expenditures (hardware, software, consulting, etc) for 2011?',
#        'What type of project are you developing?',
# ...

# %%
canadaData2012 = data2012[data2012["What Country or Region do you live in?"]==countryInterestedIn][columns2012]
canadaData2012 = canadaData2012.dropna(subset=['Including bonus, what is your annual compensation in USD?'])
# canadaData2012['Including bonus, what is your annual compensation in USD?'].unique()
canadaData2012 = canadaData2012[columns2012]
canadaData2012 = canadaData2012[~canadaData2012['Including bonus, what is your annual compensation in USD?'].isin(["Rather not say","Student / Unemployed"])]
canadaData2012
# Out:
#      Which best describes the size of your company?  \
# 14                            Fortune 1000 (1,000+)
# 132                  Mature Small Business (25-100)
# 137                             Mid Sized (100-999)
# 184                           Fortune 1000 (1,000+)
# 279                           Fortune 1000 (1,000+)
# ...                                             ...
# 6163                                Start Up (1-25)
# 6165                                Start Up (1-25)
# 6174                          Fortune 1000 (1,000+)
# 6197                            Mid Sized (100-999)
# 6199                                Start Up (1-25)
#
#      How would you best describe the industry you currently work in?  \
# 14                                               Gaming
# 132                                           Education
# 137                                              Retail
# 184                                          Consulting
# ...

# %%
canadaData2012["Year"] = 2012
canadaData2012 = canadaData2012.rename(columns={"Which best describes the size of your company?":"OrgSize","How would you best describe the industry you currently work in?":"Industry", "How many years of IT/Programming experience do you have?":"Experience","Which of the following best describes your occupation?":"Title","What Country or Region do you live in?":"Country", "Including bonus, what is your annual compensation in USD?":"Salary"})
canadaData2012 = canadaData2012[ColumnToHave]
canadaData2012
# Out:
#       Year                         OrgSize           Industry Experience  \
# 14    2012           Fortune 1000 (1,000+)             Gaming         <2
# 132   2012  Mature Small Business (25-100)          Education      41070
# 137   2012             Mid Sized (100-999)             Retail         11
# 184   2012           Fortune 1000 (1,000+)         Consulting         11
# 279   2012           Fortune 1000 (1,000+)  Software Products      41070
# ...    ...                             ...                ...        ...
# 6163  2012                 Start Up (1-25)       Web Services      40944
# 6165  2012                 Start Up (1-25)  Software Products      40944
# 6174  2012           Fortune 1000 (1,000+)         Consulting      41070
# 6197  2012             Mid Sized (100-999)              Other      40944
# 6199  2012                 Start Up (1-25)  Software Products         11
#
#                                Title Country              Salary
# ...

# %%
canadaData2012.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)

# %% [markdown]
# ## 2011

# %%
data2011 = pd.read_csv(f"{basePath}2011.csv",encoding='ISO-8859-1')
columns2011 = ["Which best describes the size of your company?","How would you best describe the industry you work in?", "How many years of IT/Programming experience do you have?","Which of the following best describes your occupation?","What Country or Region do you live in?", "Including bonus, what is your annual compensation in USD?"]
data2011.columns
# Out:
# Index(['What Country or Region do you live in?',
#        'Which US State or Territory do you live in?', 'How old are you?',
#        'How many years of IT/Programming experience do you have?',
#        'How would you best describe the industry you work in?',
#        'Which best describes the size of your company?',
#        'Which of the following best describes your occupation?',
#        'How likely is it that a recommendation you make will be acted upon?',
#        'What is your involvement in purchasing? You can choose more than 1.',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14',
#        'What types of purchases are you involved in?', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'What is your budget for outside expenditures (hardware, software, consulting, etc) for 2011?',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
# ...

# %%
data2011[columns2011]
# Out:
#      Which best describes the size of your company?  \
# 0                                          Response
# 1                                   Start Up (1-25)
# 2                    Mature Small Business (25-100)
# 3                               Mid Sized (100-999)
# 4                                           Student
# ...                                             ...
# 2809                                Start Up (1-25)
# 2810                            Mid Sized (100-999)
# 2811                 Mature Small Business (25-100)
# 2812                 Mature Small Business (25-100)
# 2813                            Mid Sized (100-999)
#
#      How would you best describe the industry you work in?  \
# 0                                              Response
# 1                                            Consulting
# 2                                     Software Products
# 3                                     Software Products
# ...

# %%
canadaData2011 = data2011[data2011["What Country or Region do you live in?"]==countryInterestedIn][columns2011]
canadaData2011 = canadaData2011.dropna(subset=['Including bonus, what is your annual compensation in USD?'])
# canadaData2011['Including bonus, what is your annual compensation in USD?'].unique()
canadaData2011 = canadaData2011[columns2011]
canadaData2011 = canadaData2011[~canadaData2011['Including bonus, what is your annual compensation in USD?'].isin(["Rather not say","Student / Unemployed"])]
canadaData2011
# Out:
#      Which best describes the size of your company?  \
# 27                   Mature Small Business (25-100)
# 65                            Fortune 1000 (1,000+)
# 71                   Mature Small Business (25-100)
# 116                                 Start Up (1-25)
# 144           Other (not working, consultant, etc.)
# ...                                             ...
# 2575                 Mature Small Business (25-100)
# 2595                                Start Up (1-25)
# 2645                                Start Up (1-25)
# 2781                 Mature Small Business (25-100)
# 2783                            Mid Sized (100-999)
#
#      How would you best describe the industry you work in?  \
# 27                                                Other
# 65                                           Healthcare
# 71                                         Web Services
# 116                                   Software Products
# ...

# %%
canadaData2011["Year"] = 2011
canadaData2011 = canadaData2011.rename(columns={"Which best describes the size of your company?":"OrgSize","How would you best describe the industry you work in?":"Industry", "How many years of IT/Programming experience do you have?":"Experience","Which of the following best describes your occupation?":"Title","What Country or Region do you live in?":"Country", "Including bonus, what is your annual compensation in USD?":"Salary"})
canadaData2011 = canadaData2011[ColumnToHave]
canadaData2011
# Out:
#       Year                                OrgSize           Industry  \
# 27    2011         Mature Small Business (25-100)              Other
# 65    2011                  Fortune 1000 (1,000+)         Healthcare
# 71    2011         Mature Small Business (25-100)       Web Services
# 116   2011                        Start Up (1-25)  Software Products
# 144   2011  Other (not working, consultant, etc.)         Consulting
# ...    ...                                    ...                ...
# 2575  2011         Mature Small Business (25-100)  Finance / Banking
# 2595  2011                        Start Up (1-25)       Web Services
# 2645  2011                        Start Up (1-25)       Web Services
# 2781  2011         Mature Small Business (25-100)       Web Services
# 2783  2011                    Mid Sized (100-999)  Software Products
#
#      Experience                      Title Country              Salary
# ...

# %%
canadaData2011.to_csv(f'{basePath}{canadianDataFileName}', mode='a', header=False, index=False)
